# %% [markdown]
# # 0.0 Imports

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import inflection
import math 
from matplotlib import pyplot as plt
from statistics import mean
from IPython.display import Image 
import datetime

# %% [markdown]
# ## 0.1 Helper Functions

# %% [markdown]
# ## 0.2 Loading Data

# %%
df_sales_raw = pd.read_csv('Data/train.csv', low_memory = False)
df_store_raw = pd.read_csv('Data/store.csv', low_memory = False)


# Merge:
#Neste merge ele pegou a tabela Store.csv e anexou ao lado direito da tab Train (Menos a linha Store que é a comum entre as duas)
#Creio que 'Left' quis dizer que a Coluna Store ficou ao lado Esquerdo de tudo.
df_raw = pd.merge( df_sales_raw, df_store_raw , how='left', on='Store')

# %%
df_raw
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a               1900.0
# 1017205            a              1         c          c               1880.0
# 1017206            a              1         a          c               9260.0
# 1017207            a              1         a          c                870.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1017204                        6.0                    2014.0       1
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                   13.0           2010.0   Jan,Apr,Jul,Oct
# 2                   14.0           2011.0   Jan,Apr,Jul,Oct
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             31.0           2013.0   Jan,Apr,Jul,Oct
# 1017205              NaN              NaN               NaN
# 1017206              NaN              NaN               NaN
# 1017207              NaN              NaN               NaN
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
df_sales_raw
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1
#
# [1017209 rows x 9 columns]

# %%
df_store_raw
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# ...                         ...                       ...     ...
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                 NaN              NaN               NaN
# 1                13.0           2010.0   Jan,Apr,Jul,Oct
# 2                14.0           2011.0   Jan,Apr,Jul,Oct
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1115 rows x 10 columns]

# %% [markdown]
# # 1.0 DESCRIÇÃO DOS DADOS

# %%
df1 = df_raw.copy()

# %%
#Agora temos todas as palavras emendadas por Underlines _  :
df1.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %% [markdown]
# ## 1.1 Rename Columns

# %%
#df_raw.columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear', 'PromoInterval']


snakecase = lambda x: inflection.underscore( x ) 

#Map -> Aplica uma função a cada item de uma lista:
#Estamos convertendo tudo para uma lista (Ali no começo):
cols_new = list(map(snakecase, cols_old ))

#Rename:
df1.columns = cols_new

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
#.Shape serve para printar linhas e colunas de um DataFrame :
#.. onde 0 significa Linhas e 1 as colunas:
print(f' Number of Rows  {df1.shape[0]}')
print(f' Number of Columns  {df1.shape[1]}')
# Out:
#  Number of Rows  1017209
#  Number of Columns  18

# %% [markdown]
# ## 1.3  Data types

# %%
#Sobrescrevemos a coluna 'date' com Ela mesma, porém convertida de 'Object' p/ o formato 'date':
df1['date'] = pd.to_datetime( df1['date'])
#Mostramos os novos resultados (Agora deixa de ser Object para ser DateTime64):
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# ## 1.4 Check NAs

# %%
#Mostra onde ha colunas vazias
#Sendo 0 igual a Nenhuma coluna vazia
# A esquerda o nome da Coluna
# A direita (Indo na vertical) A quantidade de linhas faltantes
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# ## 1.5 FillOut NAs

# %%
df1[ 'competition_distance'].max()
# Out:
# 75860.0

# %%
# competition_distance 
#..Usan um valor muito alto (200...) quando a valor da celula for nulo na tabela:
# Else -> Caso não haja um valor faltante na coluna\celula, retorna o valor que estiver la:
#Onde esta 'X' era DF1:
# Função Apply  -> Aplica esta Lambda em todas as linhas do DataSet:
# df1['competition_distance'] Na parte inicial da linha -> Especifica a coluna a qual devera ser aplicada a função:
# Repetindo "df1['competition_distance']" no Inicio da linha -> Faz com que A coluna original seja sobre-escrita
df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan( x ) else x )



# competition_open_since_month  
#Sentença -> Se a coluna 'Competition_Open_Since_Month' for Nula
#..extraia o Mês da coluna 'date':
# Else -> Caso não seja Nula -> Apenas retorna o valor nela já contido:
# SEM USAR LAMBDA -> df1['date'].month if math.isnan( df1['competition_open_since_month'] ) else df1['competition_open_since_month']
#Usabdo Lambda -> Podemos substituir 'DF1' por 'X':
# df1['competition_since_month'] =  -> Será sobrescrito pelo resultado da Lambda:
#df1['competition_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan( x['competition_open_since_month'] ) else x['competition_open_since_month'], axis = 1)
df1.competition_open_since_month.fillna(df1.date.dt.month, inplace=True)

# competition_open_since_year  
#df1['competition_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan( x['competition_open_since_year'] ) else x['competition_open_since_year'], axis = 1 )
df1.competition_open_since_year.fillna(df1.date.dt.year, inplace=True)

# promo2_since_week 
df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week if math.isnan( x['promo2_since_week'] ) else x['promo2_since_week'], axis = 1 )



# promo2_since_year               
df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan( x['promo2_since_year'] ) else x['promo2_since_year'], axis = 1 )


# promo_interval (Dicionario):
Month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov',12: 'Dec', }


#Aciona a coluna promo_interval -> Se ela for NA, Será substituida por ZERO (0)
# INPLACE=TRUE ->  Ele não retornará nenhum valor, apenas modificará a coluna:

df1['promo_interval'].fillna(0, inplace = True)

#Nova Coluna a ser criada, que recebe o Valor
#.dt -> Transforma em Data
# .month -> Transforma em Mês
# Aplica/Mapeia a Lista 'Month_map' Para substituir os numeros por letras
df1['Month_Map'] = df1['date'].dt.month.map( Month_map)

# %%
#TESTANDO PEDAÇO DO CODIGO DA CELULA DE CIMA:

# promo_interval (Dicionario):
Month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov',12: 'Dec', }


#Aciona a coluna promo_interval -> Se ela for NA, Será substituida por ZERO (0)
# INPLACE=TRUE ->  Ele não retornará nenhum valor, apenas modificará a coluna:

df1['promo_interval'].fillna(0, inplace = True)

#Nova Coluna a ser criada, que recebe o Valor
#.dt -> Transforma em Data
# .month -> Transforma/Conveter para Mês
# Aplica a Lista 'Month_map' Para substituir os numeros por letras
df1['Month_Map'] = df1['date'].dt.month.map( Month_map)

#Dividir Onde houver Virgulas (.split(',')):
#Verifica se 'df1['Month_map'] is' Esta dentro desta lista (Promo_interval)
#axis=1  -> Pois esta sendo usada mais de Uma Coluna :
#Tudo isso sera inserido numa nova coluna chamada 'is_promo':
# Se estiver no intervalo da promoção -> Retorna ZERO:
df1['is_promo'] = df1[['promo_interval', 'Month_Map']].apply(lambda x: 0 if x['promo_interval'] == 0 else 1 if x['Month_Map'] is x['promo_interval'].split(',') else 0, axis=1)

# %%
backup = df1.copy()

# %%
#NÃO FUNCIONOU
#df1.sample(25).T

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# Month_Map                       0
# is_promo                        0
# dtype: int64

# %%
# Novo Valor Máximo = 200000.0 Metro:
df1[ 'competition_distance'].max()
# Out:
# 200000.0

# %%
df3 = df1

# %%
# substitui os 0 para '', assim não será necessário um dos if's do is_promo
df3['promo_interval'].replace(0, '', inplace=True)
# mesmo aqui
df3['promo_interval'].fillna('', inplace=True) 

# obtem a abreviatura do mês  %b == Mês
df3['Month_Map'] = df3['date'].dt.strftime("%b") 

# como não tem 0's mais, tudo vai ser string, então podemos remover aqueles if's
df1['is_promo'] = df3[['promo_interval', 'Month_Map']].apply(lambda x: x['Month_Map'] in x['promo_interval'].split( ',' ), axis='columns').astype('int')

# %%
#IS_PROMO -> Funciona AQUI !!!
df3.sample(25).T
# Out:
#                                           183589               540046   \
# store                                         730                   57
# day_of_week                                     2                    2
# date                          2015-02-17 00:00:00  2014-03-04 00:00:00
# sales                                        8837                14575
# customers                                    1010                 1280
# open                                            1                    1
# promo                                           1                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      c                    d
# assortment                                      a                    c
# competition_distance                       1190.0                420.0
# competition_open_since_month                  9.0                  6.0
# competition_open_since_year                2013.0               2014.0
# promo2                                          0                    0
# promo2_since_week                             8.0                 10.0
# promo2_since_year                          2015.0               2014.0
# promo_interval
# Month_Map                                     Feb                  Mar
# is_promo                                        0                    0
#
#                                           1009970              293817   \
# store                                         566                  478
# day_of_week                                     1                    5
# date                          2013-01-07 00:00:00  2014-10-31 00:00:00
# sales                                        6623                 8322
# customers                                     671                  844
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      a                    d
# assortment                                      a                    c
# competition_distance                       3620.0               1940.0
# competition_open_since_month                  1.0                  3.0
# competition_open_since_year                2013.0               2012.0
# promo2                                          1                    0
# promo2_since_week                            40.0                 44.0
# promo2_since_year                          2013.0               2014.0
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Jan                  Oct
# is_promo                                        1                    0
#
#                                           196975               121532   \
# store                                         736                 1113
# day_of_week                                     4                    2
# date                          2015-02-05 00:00:00  2015-04-14 00:00:00
# sales                                        6105                 7075
# customers                                     544                  668
# open                                            1                    1
# promo                                           1                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      c                    a
# assortment                                      c                    c
# competition_distance                       1650.0               9260.0
# competition_open_since_month                  2.0                  4.0
# competition_open_since_year                2015.0               2015.0
# promo2                                          1                    0
# promo2_since_week                            14.0                 16.0
# promo2_since_year                          2011.0               2015.0
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Feb                  Apr
# is_promo                                        0                    0
#
#                                           478229               141424   \
# store                                         680                  935
# day_of_week                                     2                    5
# date                          2014-04-29 00:00:00  2015-03-27 00:00:00
# sales                                        5489                 6260
# customers                                     776                  660
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  1                    0
# store_type                                      c                    a
# assortment                                      a                    c
# competition_distance                        170.0              22350.0
# competition_open_since_month                  4.0                  6.0
# competition_open_since_year                2014.0               2010.0
# promo2                                          1                    0
# promo2_since_week                            35.0                 13.0
# promo2_since_year                          2012.0               2015.0
# promo_interval                   Mar,Jun,Sept,Dec
# Month_Map                                     Apr                  Mar
# is_promo                                        0                    0
#
#                                           758263               368408   ...  \
# store                                         849                  238  ...
# day_of_week                                     3                    2  ...
# date                          2013-08-21 00:00:00  2014-08-12 00:00:00  ...
# sales                                        5673                 6274  ...
# customers                                     728                 1057  ...
# open                                            1                    1  ...
# promo                                           0                    0  ...
# state_holiday                                   0                    0  ...
# school_holiday                                  0                    1  ...
# store_type                                      c                    a  ...
# assortment                                      c                    a  ...
# competition_distance                       5000.0                320.0  ...
# competition_open_since_month                  8.0                  8.0  ...
# competition_open_since_year                2013.0               2014.0  ...
# promo2                                          0                    1  ...
# promo2_since_week                            34.0                 45.0  ...
# promo2_since_year                          2013.0               2009.0  ...
# promo_interval                                         Feb,May,Aug,Nov  ...
# Month_Map                                     Aug                  Aug  ...
# is_promo                                        0                    1  ...
#
#                                           203691               158774   \
# store                                         762                  445
# day_of_week                                     5                    3
# date                          2015-01-30 00:00:00  2015-03-11 00:00:00
# sales                                        5257                 7185
# customers                                     470                 1220
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                                      c                    a
# competition_distance                       1280.0                240.0
# competition_open_since_month                  1.0                  3.0
# competition_open_since_year                2015.0               2015.0
# promo2                                          1                    0
# promo2_since_week                            10.0                 11.0
# promo2_since_year                          2013.0               2015.0
# promo_interval                   Mar,Jun,Sept,Dec
# Month_Map                                     Jan                  Mar
# is_promo                                        0                    0
#
#                                           887170               722464   \
# store                                         416                  730
# day_of_week                                     6                    7
# date                          2013-04-27 00:00:00  2013-09-22 00:00:00
# sales                                        9718                    0
# customers                                    1350                    0
# open                                            1                    0
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    c
# assortment                                      c                    a
# competition_distance                       4650.0               1190.0
# competition_open_since_month                  6.0                  9.0
# competition_open_since_year                2014.0               2013.0
# promo2                                          0                    0
# promo2_since_week                            17.0                 38.0
# promo2_since_year                          2013.0               2013.0
# promo_interval
# Month_Map                                     Apr                  Sep
# is_promo                                        0                    0
#
#                                           325160               219814   \
# store                                        1062                  160
# day_of_week                                     7                    4
# date                          2014-09-28 00:00:00  2015-01-15 00:00:00
# sales                                           0                 6127
# customers                                       0                  606
# open                                            0                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    d
# assortment                                      a                    c
# competition_distance                        190.0              17110.0
# competition_open_since_month                  9.0                 11.0
# competition_open_since_year                2012.0               2005.0
# promo2                                          1                    0
# promo2_since_week                            40.0                  3.0
# promo2_since_year                          2012.0               2015.0
# promo_interval                    Feb,May,Aug,Nov
# Month_Map                                     Sep                  Jan
# is_promo                                        0                    0
#
#                                           342599               846508   \
# store                                         679                 1009
# day_of_week                                     2                    1
# date                          2014-09-09 00:00:00  2013-06-03 00:00:00
# sales                                        9023                 6402
# customers                                    1032                  553
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    a
# assortment                                      a                    a
# competition_distance                       4140.0                230.0
# competition_open_since_month                  9.0                  7.0
# competition_open_since_year                2012.0               2004.0
# promo2                                          0                    1
# promo2_since_week                            37.0                 10.0
# promo2_since_year                          2014.0               2014.0
# promo_interval                                         Jan,Apr,Jul,Oct
# Month_Map                                     Sep                  Jun
# is_promo                                        0                    0
#
#                                           272579               531127
# store                                         803                   58
# day_of_week                                     7                    3
# date                          2014-11-23 00:00:00  2014-03-12 00:00:00
# sales                                           0                 4675
# customers                                       0                  426
# open                                            0                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                                      a                    c
# competition_distance                       1760.0               7340.0
# competition_open_since_month                 11.0                  5.0
# competition_open_since_year                2014.0               2008.0
# promo2                                          1                    1
# promo2_since_week                            10.0                 27.0
# promo2_since_year                          2014.0               2012.0
# promo_interval                   Mar,Jun,Sept,Dec      Jan,Apr,Jul,Oct
# Month_Map                                     Nov                  Mar
# is_promo                                        0                    0
#
# [20 rows x 25 columns]

# %%
df3.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# Month_Map                       0
# is_promo                        0
# dtype: int64

# %% [markdown]
# ## 1.6 Change Types

# %%
df3.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# Month_Map                               object
# is_promo                                 int64
# dtype: object

# %%
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# Month_Map                               object
# is_promo                                 int64
# dtype: object

# %%
# Comando .astype( int ) Mudou a coluna de Float64 para INT:
df3['competition_open_since_month'] = df3['competition_open_since_month'].astype( int )
df3['competition_open_since_year'] = df3['competition_open_since_year'].astype( int )

df3['promo2_since_week'] = df3['promo2_since_week'].astype( int )
df3['promo2_since_year'] = df3['promo2_since_year'].astype( int )

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
num_atributes = df3.select_dtypes( include=['int64' , 'float64'])
cat_atributes = df3.select_dtypes( exclude=['int64' , 'float64', 'datetime64[ns]'])

# %%
#num_atributes.sample(4)
cat_atributes.sample(4)
# Out:
#        state_holiday store_type assortment    promo_interval Month_Map
# 456949             0          d          c                         May
# 687843             0          a          a   Feb,May,Aug,Nov       Oct
# 912134             0          d          a   Jan,Apr,Jul,Oct       Apr
# 659450             0          a          a  Mar,Jun,Sept,Dec       Nov

# %% [markdown]
# ## 1.7.1 Numerical Atributes

# %%
# Central Tendency = mena , median
# .T Inverte -> Colunas == Linhas
ct1 = pd.DataFrame(num_atributes.apply(np.mean) ).T
ct2 = pd.DataFrame(num_atributes.apply(np.median) ).T

# Dispersão = std, min, max, range, skew, kurtosis
d1 = pd.DataFrame(num_atributes.apply( np.std)).T
d2 = pd.DataFrame(num_atributes.apply( min ) ).T
d3 = pd.DataFrame(num_atributes.apply( max ) ).T

d4 = pd.DataFrame(num_atributes.apply( lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame(num_atributes.apply( lambda x: x.skew() ) ).T
d6 = pd.DataFrame(num_atributes.apply( lambda x: x.kurtosis()  ) ).T


# Concat
m = pd.concat( [d2, d3, d4, ct1, ct2, d5, d6 ]).T.reset_index()

#Nomeando as colunas:
m.columns = ( ['Atributes', 'Min', 'Max', 'Range', 'Median', 'Std', 'Skw','Kurtosis'])

# %%
m.T
#m
# Out:
#                    0            1            2           3         4   \
# Atributes       store  day_of_week        sales   customers      open
# Min               1.0          1.0          0.0         0.0       0.0
# Max            1115.0          7.0      41551.0      7388.0       1.0
# Range          1114.0          6.0      41551.0      7388.0       1.0
# Median     558.429727     3.998341  5773.818972  633.145946  0.830107
# Std             558.0          4.0       5744.0       609.0       1.0
# Skw         -0.000955     0.001593      0.64146     1.59865 -1.758045
# Kurtosis    -1.200524    -1.246873     1.778375    7.091773  1.090723
#
#                  5               6                     7   \
# Atributes     promo  school_holiday  competition_distance
# Min             0.0             0.0                  20.0
# Max             1.0             1.0              200000.0
# Range           1.0             1.0              199980.0
# Median     0.381515        0.178647           5935.442677
# Std             0.0             0.0                2330.0
# Skw        0.487838        1.677842             10.242344
# Kurtosis  -1.762018        0.815154            147.789712
#
#                                      8                            9   \
# Atributes  competition_open_since_month  competition_open_since_year
# Min                                 1.0                       1900.0
# Max                                12.0                       2015.0
# Range                              11.0                        115.0
# Median                         6.786849                   2010.32484
# Std                                 7.0                       2012.0
# Skw                           -0.042076                    -7.235657
# Kurtosis                      -1.232607                   124.071304
#
#                  10                 11                 12        13
# Atributes    promo2  promo2_since_week  promo2_since_year  is_promo
# Min             0.0                1.0             2009.0       0.0
# Max             1.0               52.0             2015.0       1.0
# Range           1.0               51.0                6.0       1.0
# Median     0.500564          23.619033        2012.793297  0.165966
# Std             1.0               22.0             2013.0       0.0
# Skw       -0.002255           0.178723          -0.784436  1.795644
# Kurtosis  -1.999999          -1.184046          -0.210075  1.224338

# %%
#DA PAU
#sns.distplot( df3['sales'])

#DA CERTO:
# https://compucademy.net/python-seaborn-distplot-is-a-deprecated-function/
sns.distplot(df3['sales'], kde = False).set_title("Histograma de Vendas")
# Out:
# /home/dikson/.pyenv/versions/3.9.2/envs/DS_2/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Histograma de Vendas')

# %%
sns.distplot(df3['competition_distance'], kde = True).set_title("Distancia do competidor")
# Out:
# Text(0.5, 1.0, 'Distancia do competidor')

# %% [markdown]
# ## 1.7.2

# %%
#Mostra todos os valores/Tipos Unicos de cada Categoria:
cat_atributes.apply( lambda x: x.unique().shape[0] )
# Out:
# state_holiday      4
# store_type         4
# assortment         3
# promo_interval     4
# Month_Map         12
# dtype: int64

# %%
#Define que só vão ser mostradas as informações NÃO nulas em 'state_holiday' & 'sales':
aux1 = df3[(df3['state_holiday'] != '0') & (df1['sales'] > 0)]

plt.subplot(1,3,1)
sns.boxplot(x='state_holiday', y='sales' , data=aux1)

plt.subplot(1,3,2)
sns.boxplot( x='store_type', y='sales', data=aux1)

plt.subplot(1,3,3)
sns.boxplot( x='assortment', y='sales', data=aux1)
# Out:
# <AxesSubplot:xlabel='assortment', ylabel='sales'>

# %% [markdown]
# # 2.0. FEATURE ENGINERING

# %%
df2 = df3.copy()

# %% [markdown]
# ## 2.1. Mapa Mental de Hipoteses

# %%
Image('img/MindMapHypothesis.png')

# %% [markdown]
# ## 2.1. Criação Das Hipoteses

# %% [markdown]
# ### 2.1.1 Hipoteses Loja

# %% [markdown]
# **1.** Lojas com Maior Quadro De Funcionários Deveriam Vender Mais
#
# **2.** Lojas com Maior Estoque deveriam Vender Mais
#
# **3.** Lojas com Maior Porte Deveriam Vender Mais
#
# **4.** Lojas com Menor Porte Deveriam vender Menos
#
# **5.** Lojas Com Maior Sortimento Deveriam Vender Mais

# %% [markdown]
# ### 2.1.2 Hipoteses Do Produto

# %% [markdown]
# **1.** Lojas Que Investem Mais em Marketing Deveriam Vender Mais
#
# **2.** Lojas com Maior Exposição de produtos Deveriam Vender Mais
#
# **3.** Lojas com Menor preço no produtos Deveriam Vender Mais
#
# **4.** Lojas com Preços Menores por Mais tempo deveriam vender mais
#
# **5.** Lojas com Melhores promoções Deveriam Vener mais
#
# **6.** Lojas com Promoções ativas por mais tempo Deveriam Vender Mais
#
# **7.** Lojas com Mais Dias de promoção Deveriam Vender Mais
#
# **8.** Lojas com Mais promoções consecutivas deveriam vender Mais

# %% [markdown]
# ### 2.1.3 Hipoteses Tempo

# %% [markdown]
# **1.** Com Mais Feriados ; Vendem Menos
#
# **2.** Funcionam nos primeiros 6 Meses do Ano (Vendem mais)
#
# **3.** Abrem nos finais de semana; Vendem Mais
#
# **4.** Lojas Deveriam Vender mais depois do Dia 10 de Cada Mês
#
# **5.** Lojas Deveriam Vender menos aos finais de Semana
#
# **6** Lojas deveriam vender Menos durante os feriados escolares

# %% [markdown]
# ## 2.2 Lista Final De Hipoteses

# %% [markdown]
# **1** Lojas Com Maior Sortimento Deveriam Vender Mais
#
# **2** Lojas Com Competidores mais proximos deveriam vender menos
#
# **3** Lojas Com Competidores a mais tempo deveriam vender mais.

# %% [markdown]
# **4.** Lojas com Promoções ativas por mais tempo Deveriam Vender Mais
#
# **5.** Lojas com Mais Dias de promoção Deveriam Vender Mais
#
# **6.** Lojas com Mais promoções consecutivas deveriam vender Mais

# %% [markdown]
# **7.** Com Mais Feriados ; Vendem Menos
#
# **8.** Funcionam nos primeiros 6 Meses do Ano (Vendem mais)
#
# **9.** Abrem nos finais de semana; Vendem Mais
#
# **10.** Lojas Deveriam Vender mais depois do Dia 10 de Cada Mês
#
# **11.** Lojas Deveriam Vender menos aos finais de Semana
#
# **12** Lojas deveriam vender Menos durante os feriados escolares

# %% [markdown]
# ## 2.3 Feature Engineering

# %%
# # year
# # -> Extraindo Ano de Data, e Guardando Numa nova Coluna Chamada 'year'
# df2['year'] = df2['date'].dt.year

# # mounth
# df2['month'] = df2['date'].dt.month

# # day
# df2['day'] = df2['date'].dt.day

# # week of year
# df2['week_of_year'] = df2['date'].dt.weekofyear

# # year week
# df2['year_week'] = df2['date'].dt.strftime('%Y-%W')

# #QUANTO TEMPO DESDE A DATA DA COMPRA DESDE QUANDO A COMPETIÇÃO COMEÇOU


# # competition since
# # -> o 'x' esta sendo usado pois vai ser aplicada uma função Lambda | O 1 -> Se trata de todo dia 1 de cada mês:
# # -> AXIS=1  -> Devido a estarem sendo usadas Duas Colunas
# # -> Traduzindo: Aplicar a função ... Nas colunas ... de DF2:
# # -> Guarda Os Resultados Disso numa Nova Coluna Chamada 'copetition_since':
# # -> Juntou as colunas 'competition_open_since_month' & 'competition_open_since_year' EX: Na Month tinha o Mês 9 e na Year o ano 2008 == 09/2008 e
# # .. Acrescentou o Dia 1 como padrão para todas estas uniões.
# df2['competition_since'] = df2.apply( lambda x: datetime.datetime( year=x['competition_open_since_year'], month=x['competition_open_since_month'], day=1 ), axis=1 )
                                     

# # Creio que sto se refira a quantos meses a competição perdurou:
# df2['competition_time_month'] = (( df2['date'] - df2['competition_since'] )/30).apply( lambda x: x.days).astype( int )

                                     

# # promo since
# # DESDE QUANDO A PROMOÇÃO ESTA ATIVA
# df2['promo_since'] = df2['promo2_since_year'].astype( str ) + '-' + df2['promo2_since_week'].astype( str )

# #-> %w  (Minusculo) == Semana de Domingo a Domingo
# # -> Não precisa usar AXIS=1 Pois somente a coluna promo_since vai ser trabalhada:
# #-> Promo_Since esta sobreescrevendo ela mesma:
# df2['promo_since'] = df2['promo_since'].apply( lambda x:  datetime.datetime.strptime( x + '-1', '%Y-%W-%w') - datetime.timedelta( days=7) )

# #Nova coluna 'promo_time_week' -> Refere-se a qantidade de semanas em que a promoção esta ativa:
# df2['promo_time_week'] = ( ( df2['date'] - df2['promo_since']) /7 ).apply( lambda x: x.days).astype( int )


# assortment
#-> Retorna Basic IF x == a

df2['assortment'] = df2['assortment'].apply(lambda x:  'basic' if x ==  'a' else 'extra' if x == 'b' else 'extended' )

# state holiday 
#-> Creio Eu que 'x' seja um cursosr que percorre a tabela toda, e vai encontrar 'a', 'b', e 'c' na coluna 'store_type':
#.. E então inserir os retornos na coluna 'state_holiday', de acordo com a descrição no site Kaggle:
df2['state_holiday'] = df2['state_holiday'].apply( lambda x: 'public_holiday' if x == 'a' else 'easter_holiday' if x == 'b' else 'christimas' if x == 'c' else 'regular_day')

# %%
#print(df2.head(3))
df2.head(25).T
#df2['state_holiday'].head(25)
# Out:
#                                                0                    1   \
# store                                           1                    2
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064
# customers                                     555                  625
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      c                    a
# assortment                                  basic                basic
# competition_distance                       1270.0                570.0
# competition_open_since_month                    9                   11
# competition_open_since_year                  2008                 2007
# promo2                                          0                    1
# promo2_since_week                              31                   13
# promo2_since_year                            2015                 2010
# promo_interval                                         Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        0                    1
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2008-09-01 00:00:00  2007-11-01 00:00:00
# competition_time_month                         84                   94
# promo_since                   2015-07-27 00:00:00  2010-03-22 00:00:00
# promo_time_week                                 0                  279
#
#                                                2                    3   \
# store                                           3                    4
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        8314                13995
# customers                                     821                 1498
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    c
# assortment                                  basic             extended
# competition_distance                      14130.0                620.0
# competition_open_since_month                   12                    9
# competition_open_since_year                  2006                 2009
# promo2                                          1                    0
# promo2_since_week                              14                   31
# promo2_since_year                            2011                 2015
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2006-12-01 00:00:00  2009-09-01 00:00:00
# competition_time_month                        105                   71
# promo_since                   2011-03-28 00:00:00  2015-07-27 00:00:00
# promo_time_week                               226                    0
#
#                                                4                    5   \
# store                                           5                    6
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        4822                 5651
# customers                                     559                  589
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    a
# assortment                                  basic                basic
# competition_distance                      29910.0                310.0
# competition_open_since_month                    4                   12
# competition_open_since_year                  2015                 2013
# promo2                                          0                    0
# promo2_since_week                              31                   31
# promo2_since_year                            2015                 2015
# promo_interval
# Month_Map                                     Jul                  Jul
# is_promo                                        0                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2015-04-01 00:00:00  2013-12-01 00:00:00
# competition_time_month                          4                   20
# promo_since                   2015-07-27 00:00:00  2015-07-27 00:00:00
# promo_time_week                                 0                    0
#
#                                                6                    7   \
# store                                           7                    8
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                       15344                 8492
# customers                                    1414                  833
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    a
# assortment                               extended                basic
# competition_distance                      24000.0               7520.0
# competition_open_since_month                    4                   10
# competition_open_since_year                  2013                 2014
# promo2                                          0                    0
# promo2_since_week                              31                   31
# promo2_since_year                            2015                 2015
# promo_interval
# Month_Map                                     Jul                  Jul
# is_promo                                        0                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2013-04-01 00:00:00  2014-10-01 00:00:00
# competition_time_month                         28                   10
# promo_since                   2015-07-27 00:00:00  2015-07-27 00:00:00
# promo_time_week                                 0                    0
#
#                                                8                    9   ...  \
# store                                           9                   10  ...
# day_of_week                                     5                    5  ...
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00  ...
# sales                                        8565                 7185  ...
# customers                                     687                  681  ...
# open                                            1                    1  ...
# promo                                           1                    1  ...
# state_holiday                         regular_day          regular_day  ...
# school_holiday                                  1                    1  ...
# store_type                                      a                    a  ...
# assortment                               extended                basic  ...
# competition_distance                       2030.0               3160.0  ...
# competition_open_since_month                    8                    9  ...
# competition_open_since_year                  2000                 2009  ...
# promo2                                          0                    0  ...
# promo2_since_week                              31                   31  ...
# promo2_since_year                            2015                 2015  ...
# promo_interval                                                          ...
# Month_Map                                     Jul                  Jul  ...
# is_promo                                        0                    0  ...
# year                                         2015                 2015  ...
# month                                           7                    7  ...
# day                                            31                   31  ...
# week_of_year                                   31                   31  ...
# year_week                                 2015-30              2015-30  ...
# competition_since             2000-08-01 00:00:00  2009-09-01 00:00:00  ...
# competition_time_month                        182                   71  ...
# promo_since                   2015-07-27 00:00:00  2015-07-27 00:00:00  ...
# promo_time_week                                 0                    0  ...
#
#                                                15                   16  \
# store                                          16                   17
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                       10231                 8430
# customers                                     979                  946
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    a
# assortment                               extended                basic
# competition_distance                       3270.0                 50.0
# competition_open_since_month                    7                   12
# competition_open_since_year                  2015                 2005
# promo2                                          0                    1
# promo2_since_week                              31                   26
# promo2_since_year                            2015                 2010
# promo_interval                                         Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        0                    1
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2015-07-01 00:00:00  2005-12-01 00:00:00
# competition_time_month                          1                  117
# promo_since                   2015-07-27 00:00:00  2010-06-21 00:00:00
# promo_time_week                                 0                  266
#
#                                                17                   18  \
# store                                          18                   19
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                       10071                 8234
# customers                                     936                  718
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      d                    a
# assortment                               extended             extended
# competition_distance                      13840.0               3240.0
# competition_open_since_month                    6                    7
# competition_open_since_year                  2010                 2015
# promo2                                          1                    1
# promo2_since_week                              14                   22
# promo2_since_year                            2012                 2011
# promo_interval                    Jan,Apr,Jul,Oct     Mar,Jun,Sept,Dec
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2010-06-01 00:00:00  2015-07-01 00:00:00
# competition_time_month                         62                    1
# promo_since                   2012-03-26 00:00:00  2011-05-23 00:00:00
# promo_time_week                               174                  218
#
#                                                19                   20  \
# store                                          20                   21
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        9593                 9515
# customers                                     974                  682
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    1
# store_type                                      d                    c
# assortment                                  basic             extended
# competition_distance                       2340.0                550.0
# competition_open_since_month                    5                   10
# competition_open_since_year                  2009                 1999
# promo2                                          1                    1
# promo2_since_week                              40                   45
# promo2_since_year                            2014                 2009
# promo_interval                    Jan,Apr,Jul,Oct      Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    1
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2009-05-01 00:00:00  1999-10-01 00:00:00
# competition_time_month                         76                  192
# promo_since                   2014-09-29 00:00:00  2009-11-02 00:00:00
# promo_time_week                                43                  299
#
#                                                21                   22  \
# store                                          22                   23
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        6566                 7273
# customers                                     633                  560
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  0                    1
# store_type                                      a                    d
# assortment                                  basic                basic
# competition_distance                       1040.0               4060.0
# competition_open_since_month                    7                    8
# competition_open_since_year                  2015                 2005
# promo2                                          1                    0
# promo2_since_week                              22                   31
# promo2_since_year                            2012                 2015
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2015-07-01 00:00:00  2005-08-01 00:00:00
# competition_time_month                          1                  121
# promo_since                   2012-05-21 00:00:00  2015-07-27 00:00:00
# promo_time_week                               166                    0
#
#                                                23                   24
# store                                          24                   25
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                       14190                14180
# customers                                    1082                 1586
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    c
# assortment                               extended                basic
# competition_distance                       4590.0                430.0
# competition_open_since_month                    3                    4
# competition_open_since_year                  2000                 2003
# promo2                                          1                    0
# promo2_since_week                              40                   31
# promo2_since_year                            2011                 2015
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2000-03-01 00:00:00  2003-04-01 00:00:00
# competition_time_month                        187                  150
# promo_since                   2011-09-26 00:00:00  2015-07-27 00:00:00
# promo_time_week                               200                    0
#
# [29 rows x 25 columns]

# %% [markdown]
# # 3.0. PASSO 03 - FILTRAGEM DE VARIÁVEIS

# %%
df3 = df2.copy()

# %%
df3.head().T
# Out:
#                                                 0                    1  \
# store                                           1                    2
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        5263                 6064
# customers                                     555                  625
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      c                    a
# assortment                                  basic                basic
# competition_distance                       1270.0                570.0
# competition_open_since_month                    9                   11
# competition_open_since_year                  2008                 2007
# promo2                                          0                    1
# promo2_since_week                              31                   13
# promo2_since_year                            2015                 2010
# promo_interval                                         Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        0                    1
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2008-09-01 00:00:00  2007-11-01 00:00:00
# competition_time_month                         84                   94
# promo_since                   2015-07-27 00:00:00  2010-03-22 00:00:00
# promo_time_week                                 0                  279
#
#                                                 2                    3  \
# store                                           3                    4
# day_of_week                                     5                    5
# date                          2015-07-31 00:00:00  2015-07-31 00:00:00
# sales                                        8314                13995
# customers                                     821                 1498
# open                                            1                    1
# promo                                           1                    1
# state_holiday                         regular_day          regular_day
# school_holiday                                  1                    1
# store_type                                      a                    c
# assortment                                  basic             extended
# competition_distance                      14130.0                620.0
# competition_open_since_month                   12                    9
# competition_open_since_year                  2006                 2009
# promo2                                          1                    0
# promo2_since_week                              14                   31
# promo2_since_year                            2011                 2015
# promo_interval                    Jan,Apr,Jul,Oct
# Month_Map                                     Jul                  Jul
# is_promo                                        1                    0
# year                                         2015                 2015
# month                                           7                    7
# day                                            31                   31
# week_of_year                                   31                   31
# year_week                                 2015-30              2015-30
# competition_since             2006-12-01 00:00:00  2009-09-01 00:00:00
# competition_time_month                        105                   71
# promo_since                   2011-03-28 00:00:00  2015-07-27 00:00:00
# promo_time_week                               226                    0
#
#                                                 4
# store                                           5
# day_of_week                                     5
# date                          2015-07-31 00:00:00
# sales                                        4822
# customers                                     559
# open                                            1
# promo                                           1
# state_holiday                         regular_day
# school_holiday                                  1
# store_type                                      a
# assortment                                  basic
# competition_distance                      29910.0
# competition_open_since_month                    4
# competition_open_since_year                  2015
# promo2                                          0
# promo2_since_week                              31
# promo2_since_year                            2015
# promo_interval
# Month_Map                                     Jul
# is_promo                                        0
# year                                         2015
# month                                           7
# day                                            31
# week_of_year                                   31
# year_week                                 2015-30
# competition_since             2015-04-01 00:00:00
# competition_time_month                          4
# promo_since                   2015-07-27 00:00:00
# promo_time_week                                 0

# %% [markdown]
# ## 3.1. Filtragem das linhas

# %%
#CONDIÇÕES
#Que as vendas sejam Maiores que 0
# 'Open' = 0 Significa Loja fechada. Então sabemos que as vendas são 0
df3 = df3[(df3 ['open'] != 0 ) & (df3['sales'] > 0 )]

# %% [markdown]
# ## 3.2 Seleção das Colunas

# %%
#CRIA UMA LISTA COM AS COLUNAS A SEREM IGNORADAS ou EXCLUIDAS:
cols_drop = ['customers', 'open', 'promo_interval', 'Month_Map']
#Método DROP (Colunas_Definidas, axis=1 significa Colunas & axis=0 == Linhas)
#E, guarda os resultados dentro do proprio DF3:
df3 = df3.drop(cols_drop, axis=1)

# %%
#Observe que as colunas citadas em cols_drop Já não constam mais:
df3.columns
# Out:
# Index(['store', 'day_of_week', 'date', 'sales', 'promo', 'state_holiday',
#        'school_holiday', 'store_type', 'assortment', 'competition_distance',
#        'competition_open_since_month', 'competition_open_since_year', 'promo2',
#        'promo2_since_week', 'promo2_since_year', 'is_promo', 'year', 'month',
#        'day', 'week_of_year', 'year_week', 'competition_since',
#        'competition_time_month', 'promo_since', 'promo_time_week'],
#       dtype='object')
